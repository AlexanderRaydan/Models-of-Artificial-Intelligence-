# %%
import pandas as pd

# %% [markdown]
# **series**

# %%
serie = pd.Series([5,10,15,20,25]) # funciona para cualquier tipo de dato

print(serie)

serie[3]
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# dtype: int64
# 20

# %% [markdown]
# **DataFrame**

# %%
data = {'nombre': ['manaos' , 'juanito' , 'pedro'] , 'pais': ['brasil' , 'puerto rico' , 'UUEE'] }

info = pd.DataFrame(data) # lo pone todo mas bonito 
print(info)

info[['nombre']] # tambien se puede imprimir solo los modulos que quieras
# Out:
#     nombre         pais
# 0   manaos       brasil
# 1  juanito  puerto rico
# 2    pedro         UUEE
#     nombre
# 0   manaos
# 1  juanito
# 2    pedro

# %% [markdown]
# cargar desde un archivo

# %%
canciones = pd.read_csv('/content/canciones-2018_b2c776e4-1cce-40eb-b3e7-591ea6d29f83.csv')

canciones.head(5)
# Out:
#                       id  ... time_signature
# 0  6DCZcSspjsKoFjzjrWoCd  ...            4.0
# 1  3ee8Jmje8o58CHK66QrVC  ...            4.0
# 2  0e7ipj03S05BNilyu5bRz  ...            4.0
# 3  3swc6WTsr7rl9DqQKQA55  ...            4.0
# 4  2G7V7zsVDxg1yRsu7Ew9R  ...            4.0
#
# [5 rows x 16 columns]

# %%
artistas = canciones.artists  # son objetos , se les puede llamar de esta forma
nombres  = canciones.name
print(artistas[:5] , nombres[:5])
# Out:
# 0           Drake
# 1    XXXTENTACION
# 2     Post Malone
# 3     Post Malone
# 4           Drake
# Name: artists, dtype: object 0                      God's Plan
# 1                            SAD!
# 2      rockstar (feat. 21 Savage)
# 3    Psycho (feat. Ty Dolla $ign)
# 4                  In My Feelings
# Name: name, dtype: object

# %%
canciones.iloc[4] # te da toda la info en esa posicion
# Out:
# id                  2G7V7zsVDxg1yRsu7Ew9R
# name                       In My Feelings
# artists                             Drake
# danceability                        0.835
# energy                              0.626
# key                                     1
# loudness                           -5.833
# mode                                    1
# speechiness                         0.125
# acousticness                       0.0589
# instrumentalness                    6e-05
# liveness                            0.396
# valence                              0.35
# tempo                               91.03
# duration_ms                        217925
# time_signature                          4
# Name: 4, dtype: object

# %%
canciones.tail()
# Out:
#                        id  ... time_signature
# 95  630sXRhIcfwr2e4RdNtjK  ...            4.0
# 96  2xmrfQpmS2iJExTlklLoA  ...            4.0
# 97  5WvAo7DNuPRmk4APhdPzi  ...            5.0
# 98  1j4kHkkpqZRBwE0A4CN4Y  ...            4.0
# 99  3EPXxR3ImUwfayaurPi3c  ...            4.0
#
# [5 rows x 16 columns]

# %%
canciones.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
canciones.shape
# Out:
# (100, 16)

# %%
canciones.sort_index(axis = 0 , ascending= False) # ordenar de manera descendente

# %%
data = canciones[['id' , 'name' , 'artists']].head(6)

data = data.sort_index(axis = 0 , ascending= False)

data
# Out:
#                       id                          name       artists
# 5  7dt6x5M1jzdTEt8oCbisT                    Better Now   Post Malone
# 4  2G7V7zsVDxg1yRsu7Ew9R                In My Feelings         Drake
# 3  3swc6WTsr7rl9DqQKQA55  Psycho (feat. Ty Dolla $ign)   Post Malone
# 2  0e7ipj03S05BNilyu5bRz    rockstar (feat. 21 Savage)   Post Malone
# 1  3ee8Jmje8o58CHK66QrVC                          SAD!  XXXTENTACION
# 0  6DCZcSspjsKoFjzjrWoCd                    God's Plan         Drake
